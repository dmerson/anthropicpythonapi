# %%
#install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (0.105.2)
# Requirement already satisfied: python-dotenv in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.17)
# Requirement already satisfied: certifi in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\claude cowork projects\buildingwiththeclaudeapi\.venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load evn variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic
client = Anthropic()
model="claude-sonnect-4-0"

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence."
        }
    ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 message =client.messages.create(
#       2     model=model,
#       3     max_tokens=1000,
#       4     messagess=[
#
# File c:\Claude Cowork Projects\BuildingWithTheClaudeApi\.venv\Lib\site-packages\anthropic\_utils\_utils.py:293, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     291         else:
#     292             msg = f"Missing required argument: {quote(missing[0])}"
# --> 293     raise TypeError(msg)
#     294 return func(*args, **kwargs)
#
# TypeError: Missing required arguments; Expected either ('max_tokens', 'messages' and 'model') or ('max_tokens', 'messages', 'model' and 'stream') arguments to be given
